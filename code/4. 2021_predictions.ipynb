# %% [markdown]
# ## 0. Imports and Data Setup

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, StackingClassifier
from sklearn.svm import SVC
import tensorflow as tf

# %%
movies = pd.read_csv('../data/movies_1990_2020_complete.csv', index_col = 'tconst', low_memory = False)
movies_2020 = movies[movies['startYear']==2020]
movies = movies[movies['startYear']!=2020]
movies_2020 = movies_2020.fillna(0)

# %%
X_vars_all = ['runtimeMinutes', 'Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy',
 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News',
    'Reality-TV', 'Romance', 'Sci-Fi', 'Sport', 'Thriller', 'War', 
    'Warner Bros.', 'Universal Pictures', 'Columbia Pictures',
    'Paramount Pictures', 'Dreamworks Pictures', 'Walt Disney Pictures',
    'Miramax', 'Twentieth Century Fox', 'New Line Cinema', 'Focus Features',
    'Fox Searchlight Pictures', 'Touchstone Pictures',
    'Walt Disney Animation Studios', 'BBC Films', 'TriStar Pictures',
    'New Regency Productions', 'Fox 2000 Pictures', 'The Weinstein Company',
    'Annapurna Pictures', 'Castle Rock Entertainment',
     'oscars_post_release', 'US_open_WE', 'prev_Oscars', 'rel_USA', 'prev_Oscar_wins_nm', 'prev_Oscar_noms_nm', 'GG',
    'rel__aug', 'rel__dec', 'rel__feb', 'rel__jan', 'rel__jul', 'rel__jun',
    'rel__mar', 'rel__may', 'rel__nov', 'rel__oct', 'rel__sep', 'budget_USD']

# %% [markdown]
# ### 1. Predicting 2021 nominations using RFC (sel. based on cross-validation recall and precision)

# %%
nominees_2020_tconst = ['tt6772802','tt6723592','tt6878306','tt13143964','tt5198068','tt7488208', 'tt1070874', 'tt7146812', 'tt2948372', 'tt10618286', 'tt4566758','tt6048922','tt10272386', 'tt10633456', 'tt10514222', 'tt11161474',
 'tt10539608', 'tt3661394', 'tt10612922', 'tt2222042', 'tt10288566', 'tt12888462', 'tt11394298', 'tt11416746', 'tt10627584', 'tt10360862', 'tt8580274', 'tt8633462', 'tt8923484', 'tt9214832',
 'tt9620292', 'tt9770150', 'tt9777644', 'tt8333746', 'tt8521718', 'tt9586294', 'tt9784798', 'tt5363618', 'tt6571548', 'tt10706602', 'tt6193408','tt10514222']

# %%
rfc_nom = pickle.load(open('../pickles/rfc_nom.p', 'rb'))
stan_nom = pickle.load(open('../pickles/stan_nom.p', 'rb'))

# %%
movies_2020_Z = stan_nom.transform(movies_2020[X_vars_all])
tto_pred_noms = pd.DataFrame(index = movies_2020.index, columns = ['RFC_nom', 'RFC_nom_proba'],
                             data = np.array([rfc_nom.predict(movies_2020_Z), [_[1] for _ in rfc_nom.predict_proba(movies_2020_Z)]]).T)
tto_pred_noms = tto_pred_noms.merge(movies_2020[['primaryTitle', 'genres', 'runtimeMinutes']], how = 'left', left_index = True, right_index = True)
tto_pred_noms.sort_values('RFC_nom_proba', inplace= True, ascending=False)
tto_pred_noms['nominated'] = tto_pred_noms.index.isin(nominees_2020_tconst).astype(int)

tto_pred_noms.head(10)
# Out:
#             RFC_nom  RFC_nom_proba                        primaryTitle  \
# tconst
# tt5363618       1.0       0.855553                      Sound of Metal
# tt6772802       1.0       0.842464                     Hillbilly Elegy
# tt6723592       1.0       0.812510                               Tenet
# tt7146812       1.0       0.798921                              Onward
# tt5198068       1.0       0.746361                         Wolfwalkers
# tt6878306       1.0       0.701578                   News of the World
# tt2948372       1.0       0.699115                                Soul
# tt13155280      1.0       0.652947  Queen Elizabeth II: End of A Reign
# tt2850386       1.0       0.649340               The Croods: A New Age
# tt5807330       1.0       0.643586                               Tread
#
#                                 genres  runtimeMinutes  nominated
# tconst
# tt5363618                  Drama,Music           120.0          1
# tt6772802                        Drama           116.0          1
# tt6723592       Action,Sci-Fi,Thriller           150.0          1
# tt7146812   Adventure,Animation,Comedy           102.0          1
# tt5198068   Adventure,Animation,Family           103.0          1
# tt6878306       Action,Adventure,Drama           118.0          1
# tt2948372   Adventure,Animation,Comedy           100.0          1
# tt13155280       Biography,Documentary            60.0          0
# tt2850386   Adventure,Animation,Comedy            95.0          0
# tt5807330                  Documentary            89.0          0

# %% [markdown]
# #### True positives:

# %%
tto_pred_noms[(tto_pred_noms['nominated']==1) & (tto_pred_noms['RFC_nom'] == 1)]
# Out:
#             RFC_nom  RFC_nom_proba                primaryTitle  \
# tconst
# tt5363618       1.0       0.855553              Sound of Metal
# tt6772802       1.0       0.842464             Hillbilly Elegy
# tt6723592       1.0       0.812510                       Tenet
# tt7146812       1.0       0.798921                      Onward
# tt5198068       1.0       0.746361                 Wolfwalkers
# tt6878306       1.0       0.701578           News of the World
# tt2948372       1.0       0.699115                        Soul
# tt7488208       1.0       0.559584               Over the Moon
# tt13143964      1.0       0.540816  Borat Subsequent Moviefilm
#
#                                 genres  runtimeMinutes  nominated
# tconst
# tt5363618                  Drama,Music           120.0          1
# tt6772802                        Drama           116.0          1
# tt6723592       Action,Sci-Fi,Thriller           150.0          1
# tt7146812   Adventure,Animation,Comedy           102.0          1
# tt5198068   Adventure,Animation,Family           103.0          1
# tt6878306       Action,Adventure,Drama           118.0          1
# tt2948372   Adventure,Animation,Comedy           100.0          1
# tt7488208   Adventure,Animation,Comedy            95.0          1
# tt13143964                      Comedy            95.0          1

# %% [markdown]
# #### False positives:

# %%
tto_pred_noms[(tto_pred_noms['nominated']==0) & (tto_pred_noms['RFC_nom'] == 1)].sample(10)
# Out:
#             RFC_nom  RFC_nom_proba  \
# tconst
# tt6587640       1.0       0.515310
# tt11433696      1.0       0.511253
# tt12590534      1.0       0.601128
# tt13155280      1.0       0.652947
# tt5807330       1.0       0.643586
# tt12801356      1.0       0.584232
# tt12786756      1.0       0.523922
# tt2850386       1.0       0.649340
# tt10256238      1.0       0.546822
# tt9893250       1.0       0.582063
#
#                                                primaryTitle  \
# tconst
# tt6587640                                 Trolls World Tour
# tt11433696                          Solo Brathuke So Better
# tt12590534                                       Dear Santa
# tt13155280               Queen Elizabeth II: End of A Reign
# tt5807330                                             Tread
# tt12801356                                          MLK/FBI
# tt12786756              Freak Power: The Ballot or the Bomb
# tt2850386                             The Croods: A New Age
# tt10256238  Created Equal: Clarence Thomas in His Own Words
# tt9893250                                      I Care a Lot
#
#                                 genres  runtimeMinutes  nominated
# tconst
# tt6587640   Adventure,Animation,Comedy            90.0          0
# tt11433696                       Drama           122.0          0
# tt12590534          Documentary,Family            84.0          0
# tt13155280       Biography,Documentary            60.0          0
# tt5807330                  Documentary            89.0          0
# tt12801356                 Documentary           104.0          0
# tt12786756                 Documentary            94.0          0
# tt2850386   Adventure,Animation,Comedy            95.0          0
# tt10256238                 Documentary           116.0          0
# tt9893250        Comedy,Crime,Thriller           118.0          0

# %% [markdown]
# False negatives:

# %%
tto_pred_noms[(tto_pred_noms['nominated']==1) & (tto_pred_noms['RFC_nom'] == 0)]
# Out:
#             RFC_nom  RFC_nom_proba  \
# tconst
# tt4566758       0.0       0.399780
# tt8333746       0.0       0.390320
# tt9214832       0.0       0.333783
# tt11161474      0.0       0.285830
# tt10618286      0.0       0.284501
# tt10633456      0.0       0.277813
# tt6048922       0.0       0.275088
# tt1070874       0.0       0.248955
# tt10539608      0.0       0.225611
# tt10706602      0.0       0.211454
# tt8923484       0.0       0.194546
# tt2222042       0.0       0.129331
# tt8521718       0.0       0.121551
# tt8633462       0.0       0.116167
# tt9784798       0.0       0.111846
# tt9777644       0.0       0.111156
# tt10272386      0.0       0.108555
# tt6193408       0.0       0.105848
# tt3661394       0.0       0.089719
# tt10288566      0.0       0.082591
# tt10612922      0.0       0.080948
# tt10612922      0.0       0.080948
# tt9770150       0.0       0.071960
# tt10514222      0.0       0.064829
# tt9620292       0.0       0.064371
# tt10627584      0.0       0.063096
# tt11416746      0.0       0.062476
# tt10612922      0.0       0.050389
# tt10612922      0.0       0.050389
# tt12888462      0.0       0.042202
# tt11394298      0.0       0.041816
# tt9586294       0.0       0.033111
# tt6571548       0.0       0.029809
# tt8580274       0.0       0.021248
# tt10360862      0.0       0.003478
#
#                                                primaryTitle  \
# tconst
# tt4566758                                             Mulan
# tt8333746                                         Pinocchio
# tt9214832                                             Emma.
# tt11161474                                Pieces of a Woman
# tt10618286                                             Mank
# tt10633456                                           Minari
# tt6048922                                         Greyhound
# tt1070874                        The Trial of the Chicago 7
# tt10539608                                 The Midnight Sky
# tt10706602                                       Collective
# tt8923484                                         Crip Camp
# tt2222042                                 Love and Monsters
# tt8521718              The United States vs. Billie Holiday
# tt8633462                                  Quo vadis, Aida?
# tt9784798                       Judas and the Black Messiah
# tt9777644                                       Da 5 Bloods
# tt10272386                                       The Father
# tt6193408              A Shaun the Sheep Movie: Farmageddon
# tt3661394                             The One and Only Ivan
# tt10288566                                    Another Round
# tt10612922                               One Night in Miami
# tt10612922                               One Night in Miami
# tt9770150                                         Nomadland
# tt10514222                         Ma Rainey's Black Bottom
# tt9620292                             Promising Young Woman
# tt10627584                                   The Life Ahead
# tt11416746                                             Time
# tt10612922                               One Night in Miami
# tt10612922                               One Night in Miami
# tt12888462                               My Octopus Teacher
# tt11394298                                   The Mole Agent
# tt9586294                                       Better Days
# tt6571548                                   The White Tiger
# tt8580274   Eurovision Song Contest: The Story of Fire Saga
# tt10360862                        The Man Who Sold His Skin
#
#                                 genres  runtimeMinutes  nominated
# tconst
# tt4566758       Action,Adventure,Drama           115.0          1
# tt8333746                Drama,Fantasy           125.0          1
# tt9214832         Comedy,Drama,Romance           124.0          1
# tt11161474                       Drama           126.0          1
# tt10618286      Biography,Comedy,Drama           131.0          1
# tt10633456                       Drama           115.0          1
# tt6048922         Action,Drama,History            91.0          1
# tt1070874       Drama,History,Thriller           129.0          1
# tt10539608        Drama,Fantasy,Sci-Fi           118.0          1
# tt10706602                 Documentary           109.0          1
# tt8923484                  Documentary           106.0          1
# tt2222042      Action,Adventure,Comedy           109.0          1
# tt8521718        Biography,Drama,Music           130.0          1
# tt8633462                    Drama,War           101.0          1
# tt9784798      Biography,Drama,History           126.0          1
# tt9777644          Adventure,Drama,War           154.0          1
# tt10272386                       Drama            97.0          1
# tt6193408   Adventure,Animation,Comedy            86.0          1
# tt3661394       Adventure,Comedy,Drama            95.0          1
# tt10288566                Comedy,Drama           117.0          1
# tt10612922                       Drama           114.0          1
# tt10612922                       Drama           114.0          1
# tt9770150                        Drama           108.0          1
# tt10514222                 Drama,Music            94.0          1
# tt9620292         Crime,Drama,Thriller           113.0          1
# tt10627584                       Drama            94.0          1
# tt11416746                 Documentary            81.0          1
# tt10612922                       Drama           114.0          1
# tt10612922                       Drama           114.0          1
# tt12888462                 Documentary            85.0          1
# tt11394298                 Documentary            84.0          1
# tt9586294           Crime,Drama,Family           135.0          1
# tt6571548                  Crime,Drama           125.0          1
# tt8580274                 Comedy,Music           123.0          1
# tt10360862                       Drama           104.0          1

# %% [markdown]
# ### 2. Predicting 2021 winners using a Voting Classifier (based on precision-recall results from cross-validation)

# %%
winners_2020_tconst = ['tt10272386', 'tt10288566', 'tt10514222' , 'tt10618286', 'tt10633456', 'tt12888462', 'tt2948372', 'tt5363618', 'tt6723592', 'tt9620292',
                      'tt9770150', 'tt9784798']

# %%
stan_win = pickle.load(open('../pickles/stan_win.p', 'rb'))
movies_2020_Z = stan_win.transform(movies_2020[X_vars_all])

# %%
vote_win = pickle.load(open('../pickles/vote_win.p', 'rb'))

tto_pred_wins = pd.DataFrame(index = movies_2020.index, columns = ['vote_win_pred'],
                             data = vote_win.predict(movies_2020_Z))
tto_pred_wins = tto_pred_wins.merge(movies_2020[['primaryTitle', 'genres', 'runtimeMinutes']], how = 'left', left_index = True, right_index = True)
tto_pred_wins.sort_values('vote_win_pred', inplace= True, ascending=False)
tto_pred_wins['won'] = tto_pred_wins.index.isin(winners_2020_tconst).astype(int)

tto_pred_wins.head(10)
# Out:
#             vote_win_pred                primaryTitle  \
# tconst
# tt2850386               1       The Croods: A New Age
# tt5363618               1              Sound of Metal
# tt13584878              1  I Am Better Because of You
# tt4566758               1                       Mulan
# tt6673612               1                    Dolittle
# tt6772802               1             Hillbilly Elegy
# tt6878306               1           News of the World
# tt2948372               1                        Soul
# tt7146812               1                      Onward
# tt9893250               1                I Care a Lot
#
#                                 genres  runtimeMinutes  won
# tconst
# tt2850386   Adventure,Animation,Comedy            95.0    0
# tt5363618                  Drama,Music           120.0    1
# tt13584878               Drama,Romance           150.0    0
# tt4566758       Action,Adventure,Drama           115.0    0
# tt6673612      Adventure,Comedy,Family           101.0    0
# tt6772802                        Drama           116.0    0
# tt6878306       Action,Adventure,Drama           118.0    0
# tt2948372   Adventure,Animation,Comedy           100.0    1
# tt7146812   Adventure,Animation,Comedy           102.0    0
# tt9893250        Comedy,Crime,Thriller           118.0    0

# %% [markdown]
# #### True positives:

# %%
tto_pred_wins[(tto_pred_wins['won']==1) & (tto_pred_wins['vote_win_pred'] == 1)]
# Out:
#            vote_win_pred    primaryTitle                      genres  \
# tconst
# tt5363618              1  Sound of Metal                 Drama,Music
# tt2948372              1            Soul  Adventure,Animation,Comedy
# tt6723592              1           Tenet      Action,Sci-Fi,Thriller
#
#            runtimeMinutes  won
# tconst
# tt5363618           120.0    1
# tt2948372           100.0    1
# tt6723592           150.0    1

# %% [markdown]
# #### False positives:

# %%
tto_pred_wins[(tto_pred_wins['won']==0) & (tto_pred_wins['vote_win_pred'] == 1)].sample(10)
# Out:
#             vote_win_pred                          primaryTitle  \
# tconst
# tt4566758               1                                 Mulan
# tt3794354               1                    Sonic the Hedgehog
# tt13143964              1            Borat Subsequent Moviefilm
# tt9893250               1                          I Care a Lot
# tt6878306               1                     News of the World
# tt8521718               1  The United States vs. Billie Holiday
# tt6772802               1                       Hillbilly Elegy
# tt7146812               1                                Onward
# tt1634106               1                             Bloodshot
# tt2850386               1                 The Croods: A New Age
#
#                                 genres  runtimeMinutes  won
# tconst
# tt4566758       Action,Adventure,Drama           115.0    0
# tt3794354      Action,Adventure,Comedy            99.0    0
# tt13143964                      Comedy            95.0    0
# tt9893250        Comedy,Crime,Thriller           118.0    0
# tt6878306       Action,Adventure,Drama           118.0    0
# tt8521718        Biography,Drama,Music           130.0    0
# tt6772802                        Drama           116.0    0
# tt7146812   Adventure,Animation,Comedy           102.0    0
# tt1634106          Action,Drama,Sci-Fi           109.0    0
# tt2850386   Adventure,Animation,Comedy            95.0    0

# %% [markdown]
# #### False negatives:

# %%
tto_pred_wins[(tto_pred_wins['won']==1) & (tto_pred_wins['vote_win_pred'] == 0)]
# Out:
#             vote_win_pred                 primaryTitle  \
# tconst
# tt12888462              0           My Octopus Teacher
# tt9784798               0  Judas and the Black Messiah
# tt9770150               0                    Nomadland
# tt9620292               0        Promising Young Woman
# tt10272386              0                   The Father
# tt10288566              0                Another Round
# tt10514222              0     Ma Rainey's Black Bottom
# tt10633456              0                       Minari
# tt10618286              0                         Mank
#
#                              genres  runtimeMinutes  won
# tconst
# tt12888462              Documentary            85.0    1
# tt9784798   Biography,Drama,History           126.0    1
# tt9770150                     Drama           108.0    1
# tt9620292      Crime,Drama,Thriller           113.0    1
# tt10272386                    Drama            97.0    1
# tt10288566             Comedy,Drama           117.0    1
# tt10514222              Drama,Music            94.0    1
# tt10633456                    Drama           115.0    1
# tt10618286   Biography,Comedy,Drama           131.0    1

# %% [markdown]
# ## 3. Predicting 2021 Best Picture nominees using RFC (based on precision-recall results from cross-validation)

# %%
bp_nominees_2020_tconst = ['tt10633456', 'tt1070874', 'tt10272386', 'tt10618286', 'tt9770150', 'tt9784798', 'tt5363618', 'tt9620292']

# %%
rfc_bp= pickle.load(open('../pickles/rfc_bp.p', 'rb'))
stan_bp = pickle.load(open('../pickles/stan_bp.p', 'rb'))

# %%
movies_2020_Z = stan_bp.transform(movies_2020[X_vars_all])
tto_pred_noms = pd.DataFrame(index = movies_2020.index, columns = ['RFC_bp_nom', 'RFC_bp_proba'],
                             data = np.array([rfc_bp.predict(movies_2020_Z), [_[1] for _ in rfc_bp.predict_proba(movies_2020_Z)]]).T)
tto_pred_noms = tto_pred_noms.merge(movies_2020[['primaryTitle', 'genres', 'runtimeMinutes']], how = 'left', left_index = True, right_index = True)
tto_pred_noms.sort_values('RFC_bp_proba', inplace= True, ascending=False)
tto_pred_noms['nominated'] = tto_pred_noms.index.isin(bp_nominees_2020_tconst).astype(int)

tto_pred_noms.head(10)
# Out:
#             RFC_bp_nom  RFC_bp_proba                primaryTitle  \
# tconst
# tt6772802          1.0      0.669925             Hillbilly Elegy
# tt6723592          1.0      0.559960                       Tenet
# tt7146812          0.0      0.499911                      Onward
# tt6878306          0.0      0.399946           News of the World
# tt2850386          0.0      0.379942       The Croods: A New Age
# tt2948372          0.0      0.369944                        Soul
# tt13143964         0.0      0.339950  Borat Subsequent Moviefilm
# tt7504726          0.0      0.319900        The Call of the Wild
# tt5198068          0.0      0.289940                 Wolfwalkers
# tt6048922          0.0      0.269846                   Greyhound
#
#                                 genres  runtimeMinutes  nominated
# tconst
# tt6772802                        Drama           116.0          0
# tt6723592       Action,Sci-Fi,Thriller           150.0          0
# tt7146812   Adventure,Animation,Comedy           102.0          0
# tt6878306       Action,Adventure,Drama           118.0          0
# tt2850386   Adventure,Animation,Comedy            95.0          0
# tt2948372   Adventure,Animation,Comedy           100.0          0
# tt13143964                      Comedy            95.0          0
# tt7504726       Adventure,Drama,Family           100.0          0
# tt5198068   Adventure,Animation,Family           103.0          0
# tt6048922         Action,Drama,History            91.0          0

# %% [markdown]
# #### True positives

# %%
tto_pred_noms[(tto_pred_noms['nominated']==1) & (tto_pred_noms['RFC_bp_nom'] == 1)]
# Out:
# Empty DataFrame
# Columns: [RFC_bp_nom, RFC_bp_proba, primaryTitle, genres, runtimeMinutes, nominated]
# Index: []

# %% [markdown]
# #### False positives

# %%
tto_pred_noms[(tto_pred_noms['nominated']==0) & (tto_pred_noms['RFC_bp_nom'] == 1)]
# Out:
#            RFC_bp_nom  RFC_bp_proba     primaryTitle                  genres  \
# tconst
# tt6772802         1.0      0.669925  Hillbilly Elegy                   Drama
# tt6723592         1.0      0.559960            Tenet  Action,Sci-Fi,Thriller
#
#            runtimeMinutes  nominated
# tconst
# tt6772802           116.0          0
# tt6723592           150.0          0

# %% [markdown]
# #### False negatives

# %%
tto_pred_noms[(tto_pred_noms['nominated']==1) & (tto_pred_noms['RFC_bp_nom'] == 0)]
# Out:
#             RFC_bp_nom  RFC_bp_proba                 primaryTitle  \
# tconst
# tt10633456         0.0      0.199916                       Minari
# tt10272386         0.0      0.159926                   The Father
# tt5363618          0.0      0.139942               Sound of Metal
# tt10618286         0.0      0.119964                         Mank
# tt1070874          0.0      0.099971   The Trial of the Chicago 7
# tt9784798          0.0      0.029925  Judas and the Black Messiah
# tt9620292          0.0      0.009981        Promising Young Woman
# tt9770150          0.0      0.000000                    Nomadland
#
#                              genres  runtimeMinutes  nominated
# tconst
# tt10633456                    Drama           115.0          1
# tt10272386                    Drama            97.0          1
# tt5363618               Drama,Music           120.0          1
# tt10618286   Biography,Comedy,Drama           131.0          1
# tt1070874    Drama,History,Thriller           129.0          1
# tt9784798   Biography,Drama,History           126.0          1
# tt9620292      Crime,Drama,Thriller           113.0          1
# tt9770150                     Drama           108.0          1

# %% [markdown]
# ## 4. Predicting 2021 Best Picture winner

# %% [markdown]
# Based on poor results of trained classifiers on test data and in cross-validation, I did not attempt to apply any of them to predicting the Best Picture.
