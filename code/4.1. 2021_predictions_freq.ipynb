# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import pickle

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

#np.random.seed(113)

# %% [markdown]
# ## Setup (display format, reading in data and previously trained estimator)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
colors = ['#dbbd5a', '#d2ad32', '#ae8e25']  #shades of "gold", from lightest to darkest (with help from icolorpalette.com)
cmap_name_ = 'golds'
golds = LinearSegmentedColormap.from_list(cmap_name_, colors, N=100)

colors_ext = ['#f5edd3', '#ecddab', '#e4cd82', '#dbbd5a', '#d2ad32', '#ae8e25', '#866d1c', '#5e4c14', '#352b0b']  #shades of "gold", from lightest to darkest (with help from icolorpalette.com)
name = 'golds_ext'
golds_ext = LinearSegmentedColormap.from_list(name, colors_ext, N=100)

# %%
titles = pd.read_csv('../data/title_basics_1990_2020.csv', index_col = 'tconst')

movies = pd.read_csv('../data/movies_1990_2020_with_detail_oscars_complete.csv', index_col= 'tconst', low_memory=False)

movies_2020 = movies[movies['startYear']==2020] # the 2020 ceremony took place on 2/9/2020, so all movies made that year can be considered potential contenders for 2021 (release dates are susceptible to nans and thus less reliable than startYear)
movies = movies[movies['startYear']<2020]

movies_btstrp = pd.concat([movies, movies[movies['Oscars']==1].sample(n = 100000, replace = True, random_state=113)], axis = 0)

# %%
X_vars_all = ['runtimeMinutes', 'Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy',
       'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News',
       'Reality-TV', 'Romance', 'Sci-Fi', 'Sport', 'Thriller', 'War', 
       'Warner Bros.', 'Universal Pictures', 'Columbia Pictures',
       'Paramount Pictures', 'Dreamworks Pictures', 'Walt Disney Pictures',
       'Miramax', 'Twentieth Century Fox', 'New Line Cinema', 'Focus Features',
       'Fox Searchlight Pictures', 'Touchstone Pictures',
       'Walt Disney Animation Studios', 'BBC Films', 'TriStar Pictures',
       'New Regency Productions', 'Fox 2000 Pictures', 'The Weinstein Company',
       'Annapurna Pictures', 'Castle Rock Entertainment',
        'oscars_post_release', 'US_open_WE', 'prev_Oscars', 'rel_USA', 'prev_Oscar_wins_nm', 'prev_Oscar_noms_nm', 'GG',
       'rel__aug', 'rel__dec', 'rel__feb', 'rel__jan', 'rel__jul', 'rel__jun',
       'rel__mar', 'rel__may', 'rel__nov', 'rel__oct', 'rel__sep',
             'budget_USD']

# %% [markdown]
# ## Scaling independent variables

# %% [markdown]
# ### Approach #1: scaling data to the historical data on which classifier was trained

# %%
X = movies_btstrp[X_vars_all]

X_train, X_test = train_test_split(X)

stan_t = StandardScaler()
stan_t.fit(X_train)

movies_2020_Z = stan_t.transform(movies_2020[X_vars_all])

# %% [markdown]
# ### Approach #2: scaling data to itself (without seeing historical data on which classifier was trained)

# %%
#stan = StandardScaler()

#movies_2020_Z = stan.fit_transform(movies_2020[X_vars_all])

# %% [markdown]
# ## Predicting 2021 nominations

# %%
rfc_nom = pickle.load(open('../pickles/rfc_nom.p', 'rb'))

# %%
tto_pred_noms = pd.DataFrame(index = movies_2020.index, columns = ['RFC_win_nom', 'RFC_win_nom_proba'], 
                         data = np.array([rfc_nom.predict(movies_2020_Z), [_[1] for _ in rfc_nom.predict_proba(movies_2020_Z)]]).T)
tto_pred_noms = tto_pred_noms.merge(titles[['primaryTitle', 'genres', 'runtimeMinutes']], how = 'left', left_index = True, right_index = True)
tto_pred_noms.sort_values('RFC_win_nom_proba', inplace= True, ascending=False)

tto_pred_noms.head(10)
# Out:
#             RFC_win_nom  RFC_win_nom_proba  \
# tconst
# tt13623860          1.0           0.761950
# tt13642438          1.0           0.761950
# tt6772802           1.0           0.740000
# tt7146812           1.0           0.720000
# tt12239604          1.0           0.720000
# tt13155280          1.0           0.631905
# tt5198068           1.0           0.620000
# tt13430676          1.0           0.587819
# tt6723592           1.0           0.550000
# tt2948372           1.0           0.530000
#
#                                   primaryTitle                      genres  \
# tconst
# tt13623860                      Laura's Choice                 Documentary
# tt13642438                     No Turning Back                 Documentary
# tt6772802                      Hillbilly Elegy                       Drama
# tt7146812                               Onward  Adventure,Animation,Comedy
# tt12239604                    Paint Until Dawn                 Documentary
# tt13155280  Queen Elizabeth II: End of A Reign       Biography,Documentary
# tt5198068                          Wolfwalkers  Adventure,Animation,Family
# tt13430676                               Birth                 Documentary
# tt6723592                                Tenet      Action,Sci-Fi,Thriller
# tt2948372                                 Soul  Adventure,Animation,Comedy
#
#            runtimeMinutes
# tconst
# tt13623860            106
# tt13642438            106
# tt6772802             116
# tt7146812             102
# tt12239604            100
# tt13155280             60
# tt5198068             103
# tt13430676            102
# tt6723592             150
# tt2948372             100

# %%
tto_pred_top10_ind = tto_pred_noms[tto_pred_noms['RFC_win_nom_proba']>=tto_pred_noms.iloc[10,1]].index
movies_2020.loc[tto_pred_top10_ind,['primaryTitle', 'genres', 'runtimeMinutes', 'summary', 'produced_by', 'rel_date', 'budget_USD', 'usa_open_we', 'prev_Oscars', 'nominated_for']]
# Out:
#                                   primaryTitle                      genres  \
# tconst
# tt13623860                      Laura's Choice                 Documentary
# tt13642438                     No Turning Back                 Documentary
# tt6772802                      Hillbilly Elegy                       Drama
# tt7146812                               Onward  Adventure,Animation,Comedy
# tt12239604                    Paint Until Dawn                 Documentary
# tt13155280  Queen Elizabeth II: End of A Reign       Biography,Documentary
# tt5198068                          Wolfwalkers  Adventure,Animation,Family
# tt13430676                               Birth                 Documentary
# tt6723592                                Tenet      Action,Sci-Fi,Thriller
# tt2948372                                 Soul  Adventure,Animation,Comedy
# tt6878306                    News of the World      Action,Adventure,Drama
#
#             runtimeMinutes                                            summary  \
# tconst
# tt13623860           106.0  Three generations of women navigate a radical ...
# tt13642438           106.0                                                NaN
# tt6772802            116.0  An urgent phone call pulls a Yale Law student ...
# tt7146812            102.0  Two elven brothers embark on a quest to bring ...
# tt12239604           100.0  ing is to painting what listening is to politi...
# tt13155280            60.0  Ever wonder what it would be like to be royalt...
# tt5198068            103.0  A young apprentice hunter and her father journ...
# tt13430676           102.0  Everyone is born, but how many of us understan...
# tt6723592            150.0  Armed with only one word, Tenet, and fighting ...
# tt2948372            100.0  After landing the gig of a lifetime, a New Yor...
# tt6878306            118.0  A Civil War veteran agrees to deliver a girl, ...
#
#                                                   produced_by  \
# tconst
# tt13623860                Factor 30 Films, Virgo Productions
# tt13642438                                         Not listed
# tt6772802                     Imagine Entertainment, Netflix
# tt7146812      Walt Disney Pictures, Pixar Animation Studios
# tt12239604                                    Lumikalai Film
# tt13155280                                         Not listed
# tt5198068    Apple Original Films, Cartoon Saloon, Mélusin...
# tt13430676                                         Not listed
# tt6723592                              Warner Bros., Syncopy
# tt2948372      Walt Disney Pictures, Pixar Animation Studios
# tt6878306    Perfect World Pictures, Playtone, Pretty Pict...
#
#                      rel_date    budget_USD  usa_open_we  prev_Oscars  \
# tconst
# tt13623860   12 December 2020  2.424088e+05          NaN          0.0
# tt13642438   18 December 2020  2.424088e+05          NaN          0.0
# tt6772802    24 November 2020  2.424088e+05          NaN         41.0
# tt7146812        6 March 2020  2.424088e+05   39119861.0         15.0
# tt12239604        8 June 2020  7.644454e+04          NaN          0.0
# tt13155280       14 July 2020  2.424088e+05          NaN          0.0
# tt5198068    13 November 2020  2.424088e+05          NaN          5.0
# tt13430676     7 October 2020  2.424088e+05          NaN          0.0
# tt6723592    3 September 2020  2.050000e+08   20200000.0         16.0
# tt2948372    25 December 2020  2.424088e+05          NaN         10.0
# tt6878306    25 December 2020  2.424088e+05    2250430.0         32.0
#
#                              nominated_for
# tconst
# tt13623860                            None
# tt13642438                            None
# tt6772802    Nominated for 1 Golden Globe.
# tt7146812    Nominated for 1 Golden Globe.
# tt12239604                            None
# tt13155280                            None
# tt5198068    Nominated for 1 Golden Globe.
# tt13430676                            None
# tt6723592    Nominated for 1 Golden Globe.
# tt2948372   Nominated for 2 Golden Globes.
# tt6878306   Nominated for 2 Golden Globes.

# %% [markdown]
# ## Predicting 2021 wins (any category)

# %%
rfc_win = pickle.load(open('../pickles/rfc_win.p', 'rb'))

# %%
tto_pred_wins = pd.DataFrame(index = movies_2020.index, columns = ['RFC_win', 'RFC_win_proba'], 
                         data = np.array([rfc_win.predict(movies_2020_Z), [_[1] for _ in rfc_win.predict_proba(movies_2020_Z)]]).T)
tto_pred_wins = tto_pred_wins.merge(titles[['primaryTitle', 'genres', 'runtimeMinutes']], how = 'left', left_index = True, right_index = True)
tto_pred_wins.sort_values('RFC_win_proba', inplace= True, ascending=False)

tto_pred_wins.head(20)
# Out:
#             RFC_win  RFC_win_proba                primaryTitle  \
# tconst
# tt6772802       0.0           0.42             Hillbilly Elegy
# tt6723592       0.0           0.28                       Tenet
# tt6878306       0.0           0.21           News of the World
# tt7146812       0.0           0.12                      Onward
# tt2948372       0.0           0.10                        Soul
# tt6048922       0.0           0.08                   Greyhound
# tt9893250       0.0           0.08                I Care a Lot
# tt1070874       0.0           0.07  The Trial of the Chicago 7
# tt13143964      0.0           0.06  Borat Subsequent Moviefilm
# tt12489826      0.0           0.06                      WMTv17
# tt7294150       0.0           0.06           The Eight Hundred
# tt10633456      0.0           0.06                      Minari
# tt2850386       0.0           0.06       The Croods: A New Age
# tt10618286      0.0           0.06                        Mank
# tt7983894       0.0           0.05                    Ammonite
# tt10515926      0.0           0.05               Half Brothers
# tt5198068       0.0           0.05                 Wolfwalkers
# tt5420210       0.0           0.05          The Comeback Trail
# tt7435316       0.0           0.05                 The Glorias
# tt6285944       0.0           0.05                  The Banker
#
#                                 genres runtimeMinutes
# tconst
# tt6772802                        Drama            116
# tt6723592       Action,Sci-Fi,Thriller            150
# tt6878306       Action,Adventure,Drama            118
# tt7146812   Adventure,Animation,Comedy            102
# tt2948372   Adventure,Animation,Comedy            100
# tt6048922         Action,Drama,History             91
# tt9893250        Comedy,Crime,Thriller            118
# tt1070874       Drama,History,Thriller            129
# tt13143964                      Comedy             95
# tt12489826      Biography,Comedy,Drama            120
# tt7294150         Action,Drama,History            149
# tt10633456                       Drama            115
# tt2850386   Adventure,Animation,Comedy             95
# tt10618286      Biography,Comedy,Drama            131
# tt7983894      Biography,Drama,Romance            120
# tt10515926                Comedy,Drama             96
# tt5198068   Adventure,Animation,Family            103
# tt5420210                 Comedy,Crime            104
# tt7435316      Biography,Drama,History            139
# tt6285944              Biography,Drama            120

# %%
tto_pred_top10_ind = tto_pred_wins[tto_pred_wins['RFC_win_proba']>=tto_pred_wins.iloc[10,1]].index
movies_2020.loc[tto_pred_top10_ind,['primaryTitle', 'genres', 'runtimeMinutes', 'summary', 'produced_by', 'rel_date', 'budget_USD', 'usa_open_we', 'prev_Oscars', 'nominated_for']]
# Out:
#                           primaryTitle                      genres  \
# tconst
# tt6772802              Hillbilly Elegy                       Drama
# tt6723592                        Tenet      Action,Sci-Fi,Thriller
# tt6878306            News of the World      Action,Adventure,Drama
# tt7146812                       Onward  Adventure,Animation,Comedy
# tt2948372                         Soul  Adventure,Animation,Comedy
# tt6048922                    Greyhound        Action,Drama,History
# tt9893250                 I Care a Lot       Comedy,Crime,Thriller
# tt1070874   The Trial of the Chicago 7      Drama,History,Thriller
# tt13143964  Borat Subsequent Moviefilm                      Comedy
# tt12489826                      WMTv17      Biography,Comedy,Drama
# tt7294150            The Eight Hundred        Action,Drama,History
# tt10633456                      Minari                       Drama
# tt2850386        The Croods: A New Age  Adventure,Animation,Comedy
# tt10618286                        Mank      Biography,Comedy,Drama
#
#             runtimeMinutes                                            summary  \
# tconst
# tt6772802            116.0  An urgent phone call pulls a Yale Law student ...
# tt6723592            150.0  Armed with only one word, Tenet, and fighting ...
# tt6878306            118.0  A Civil War veteran agrees to deliver a girl, ...
# tt7146812            102.0  Two elven brothers embark on a quest to bring ...
# tt2948372            100.0  After landing the gig of a lifetime, a New Yor...
# tt6048922             91.0  veral months after the U.S. entry into World W...
# tt9893250            118.0  A crooked legal guardian who drains the saving...
# tt1070874            129.0  The story of 7 people on trial stemming from v...
# tt13143964            95.0  Follow-up film to the 2006 comedy centering on...
# tt12489826           120.0  WMTv17 is a Video Tv Program formed by a singe...
# tt7294150            149.0  From the acclaimed filmmaker behind Mr. Six co...
# tt10633456           115.0   A Korean family starts a farm in 1980s Arkansas.
# tt2850386             95.0  The prehistoric family the Croods are challeng...
# tt10618286           131.0  1930's Hollywood is reevaluated through the ey...
#
#                                                   produced_by  \
# tconst
# tt6772802                     Imagine Entertainment, Netflix
# tt6723592                              Warner Bros., Syncopy
# tt6878306    Perfect World Pictures, Playtone, Pretty Pict...
# tt7146812      Walt Disney Pictures, Pixar Animation Studios
# tt2948372      Walt Disney Pictures, Pixar Animation Studios
# tt6048922    Sony Pictures Entertainment (SPE), Stage 6 Fi...
# tt9893250                  Black Bear Pictures, Crimple Beck
# tt1070874    Dreamworks Pictures, Amblin Partners, Apertur...
# tt13143964                 Amazon Studios, Four by Two Films
# tt12489826                                      Bongo Movies
# tt7294150    Beijing Diqi Yinxiang Entertainment, Huayi Br...
# tt10633456                              Plan B Entertainment
# tt2850386                               DreamWorks Animation
# tt10618286                                           Netflix
#
#                      rel_date   budget_USD  usa_open_we  prev_Oscars  \
# tconst
# tt6772802    24 November 2020     242408.8          NaN         41.0
# tt6723592    3 September 2020  205000000.0   20200000.0         16.0
# tt6878306    25 December 2020     242408.8    2250430.0         32.0
# tt7146812        6 March 2020     242408.8   39119861.0         15.0
# tt2948372    25 December 2020     242408.8          NaN         10.0
# tt6048922        10 July 2020   50300000.0          NaN         30.0
# tt9893250    19 February 2021     242408.8          NaN          8.0
# tt1070874     16 October 2020     242408.8          NaN         15.0
# tt13143964    23 October 2020     242408.8          NaN         29.0
# tt12489826       2 April 2020    9876589.0          NaN          0.0
# tt7294150      28 August 2020   80000000.0     118161.0          2.0
# tt10633456   12 February 2021     242408.8          NaN         16.0
# tt2850386    25 November 2020     242408.8    9724200.0         19.0
# tt10618286    4 December 2020     242408.8          NaN         33.0
#
#                              nominated_for
# tconst
# tt6772802    Nominated for 1 Golden Globe.
# tt6723592    Nominated for 1 Golden Globe.
# tt6878306   Nominated for 2 Golden Globes.
# tt7146812    Nominated for 1 Golden Globe.
# tt2948372   Nominated for 2 Golden Globes.
# tt6048922                             None
# tt9893250    Nominated for 1 Golden Globe.
# tt1070874                             None
# tt13143964  Nominated for 3 Golden Globes.
# tt12489826                            None
# tt7294150                             None
# tt10633456                            None
# tt2850386    Nominated for 1 Golden Globe.
# tt10618286                            None

# %% [markdown]
# ## Predicting 2021 nominations in the Best Picture category

# %%
rfc_bp = pickle.load(open('../pickles/rfc_bp.p', 'rb'))

# %%
tto_bp_preds = pd.DataFrame(index = movies_2020.index, columns = ['RFC_bp', 'RFC_bp_proba'], 
                         data = np.array([rfc_bp.predict(movies_2020_Z), [_[1] for _ in rfc_bp.predict_proba(movies_2020_Z)]]).T)
tto_bp_preds = tto_bp_preds.merge(titles[['primaryTitle', 'genres', 'runtimeMinutes']], how = 'left', left_index = True, right_index = True)
tto_bp_preds.sort_values('RFC_bp_proba', inplace= True, ascending=False)

tto_bp_preds.head(15)
# Out:
#             RFC_bp  RFC_bp_proba                primaryTitle  \
# tconst
# tt6772802      0.0          0.43             Hillbilly Elegy
# tt6723592      0.0          0.40                       Tenet
# tt6878306      0.0          0.29           News of the World
# tt13143964     0.0          0.19  Borat Subsequent Moviefilm
# tt2948372      0.0          0.18                        Soul
# tt10539608     0.0          0.14            The Midnight Sky
# tt10618286     0.0          0.14                        Mank
# tt2850386      0.0          0.13       The Croods: A New Age
# tt7146812      0.0          0.10                      Onward
# tt5198068      0.0          0.10                 Wolfwalkers
# tt0805647      0.0          0.10                 The Witches
# tt9893250      0.0          0.10                I Care a Lot
# tt10161886     0.0          0.09                    The Prom
# tt1070874      0.0          0.08  The Trial of the Chicago 7
# tt1051906      0.0          0.08           The Invisible Man
#
#                                 genres runtimeMinutes
# tconst
# tt6772802                        Drama            116
# tt6723592       Action,Sci-Fi,Thriller            150
# tt6878306       Action,Adventure,Drama            118
# tt13143964                      Comedy             95
# tt2948372   Adventure,Animation,Comedy            100
# tt10539608        Drama,Fantasy,Sci-Fi            118
# tt10618286      Biography,Comedy,Drama            131
# tt2850386   Adventure,Animation,Comedy             95
# tt7146812   Adventure,Animation,Comedy            102
# tt5198068   Adventure,Animation,Family            103
# tt0805647      Adventure,Comedy,Family            106
# tt9893250        Comedy,Crime,Thriller            118
# tt10161886        Comedy,Drama,Musical            130
# tt1070874       Drama,History,Thriller            129
# tt1051906         Drama,Horror,Mystery            124

# %%
tto_bp_preds_top10_ind = tto_bp_preds[tto_bp_preds['RFC_bp_proba']>tto_bp_preds.iloc[10,1]].index
movies_2020.loc[tto_bp_preds_top10_ind,['primaryTitle', 'genres', 'runtimeMinutes', 'summary', 'produced_by', 'rel_date', 'budget_USD', 'usa_open_we', 'prev_Oscars', 'nominated_for']]
# Out:
#                           primaryTitle                      genres  \
# tconst
# tt6772802              Hillbilly Elegy                       Drama
# tt6723592                        Tenet      Action,Sci-Fi,Thriller
# tt6878306            News of the World      Action,Adventure,Drama
# tt13143964  Borat Subsequent Moviefilm                      Comedy
# tt2948372                         Soul  Adventure,Animation,Comedy
# tt10539608            The Midnight Sky        Drama,Fantasy,Sci-Fi
# tt10618286                        Mank      Biography,Comedy,Drama
# tt2850386        The Croods: A New Age  Adventure,Animation,Comedy
#
#             runtimeMinutes                                            summary  \
# tconst
# tt6772802            116.0  An urgent phone call pulls a Yale Law student ...
# tt6723592            150.0  Armed with only one word, Tenet, and fighting ...
# tt6878306            118.0  A Civil War veteran agrees to deliver a girl, ...
# tt13143964            95.0  Follow-up film to the 2006 comedy centering on...
# tt2948372            100.0  After landing the gig of a lifetime, a New Yor...
# tt10539608           118.0  This post-apocalyptic tale follows Augustine, ...
# tt10618286           131.0  1930's Hollywood is reevaluated through the ey...
# tt2850386             95.0  The prehistoric family the Croods are challeng...
#
#                                                   produced_by  \
# tconst
# tt6772802                     Imagine Entertainment, Netflix
# tt6723592                              Warner Bros., Syncopy
# tt6878306    Perfect World Pictures, Playtone, Pretty Pict...
# tt13143964                 Amazon Studios, Four by Two Films
# tt2948372      Walt Disney Pictures, Pixar Animation Studios
# tt10539608   Anonymous Content, Netflix, Smokehouse Pictures
# tt10618286                                           Netflix
# tt2850386                               DreamWorks Animation
#
#                      rel_date   budget_USD  usa_open_we  prev_Oscars  \
# tconst
# tt6772802    24 November 2020     242408.8          NaN         41.0
# tt6723592    3 September 2020  205000000.0   20200000.0         16.0
# tt6878306    25 December 2020     242408.8    2250430.0         32.0
# tt13143964    23 October 2020     242408.8          NaN         29.0
# tt2948372    25 December 2020     242408.8          NaN         10.0
# tt10539608   23 December 2020     242408.8          NaN         25.0
# tt10618286    4 December 2020     242408.8          NaN         33.0
# tt2850386    25 November 2020     242408.8    9724200.0         19.0
#
#                              nominated_for
# tconst
# tt6772802    Nominated for 1 Golden Globe.
# tt6723592    Nominated for 1 Golden Globe.
# tt6878306   Nominated for 2 Golden Globes.
# tt13143964  Nominated for 3 Golden Globes.
# tt2948372   Nominated for 2 Golden Globes.
# tt10539608                            None
# tt10618286                            None
# tt2850386    Nominated for 1 Golden Globe.

# %% [markdown]
# ## Predicting 2021 winners in the Best Picture category

# %%
rfc_bp_win = pickle.load(open('../pickles/rfc_bp_win.p', 'rb'))

# %%
tto_bp_win_preds = pd.DataFrame(index = movies_2020.index, columns = ['RFC_bp', 'RFC_bp_win_proba'], 
                         data = np.array([rfc_bp_win.predict(movies_2020_Z), [_[1] for _ in rfc_bp_win.predict_proba(movies_2020_Z)]]).T)
tto_bp_win_preds = tto_bp_win_preds.merge(titles[['primaryTitle', 'genres', 'runtimeMinutes']], how = 'left', left_index = True, right_index = True)
tto_bp_win_preds.sort_values('RFC_bp_win_proba', inplace= True, ascending=False)

tto_bp_win_preds.head(10)
# Out:
#             RFC_bp  RFC_bp_win_proba                   primaryTitle  \
# tconst
# tt1070874      0.0              0.09     The Trial of the Chicago 7
# tt9893250      0.0              0.06                   I Care a Lot
# tt6878306      0.0              0.04              News of the World
# tt7510346      0.0              0.04                    The Turning
# tt7435316      0.0              0.02                    The Glorias
# tt2420124      0.0              0.02                          Wendy
# tt10243992     0.0              0.01                 I'm Your Woman
# tt12888358     0.0              0.01  John Williams: Live in Vienna
# tt5198068      0.0              0.01                    Wolfwalkers
# tt6723592      0.0              0.01                          Tenet
#
#                                 genres runtimeMinutes
# tconst
# tt1070874       Drama,History,Thriller            129
# tt9893250        Comedy,Crime,Thriller            118
# tt6878306       Action,Adventure,Drama            118
# tt7510346         Drama,Horror,Mystery             94
# tt7435316      Biography,Drama,History            139
# tt2420124                Drama,Fantasy            111
# tt10243992                 Crime,Drama            120
# tt12888358                       Music            128
# tt5198068   Adventure,Animation,Family            103
# tt6723592       Action,Sci-Fi,Thriller            150

# %%
tto_bp_win_preds_top10_ind = tto_bp_win_preds[tto_bp_win_preds['RFC_bp_win_proba']>=tto_bp_win_preds.iloc[10,1]].index
movies_2020.loc[tto_bp_win_preds_top10_ind,['primaryTitle', 'genres', 'runtimeMinutes', 'summary', 'produced_by', 'rel_date', 'budget_USD', 'usa_open_we', 'prev_Oscars', 'nominated_for']]
# Out:
#                              primaryTitle                      genres  \
# tconst
# tt1070874      The Trial of the Chicago 7      Drama,History,Thriller
# tt9893250                    I Care a Lot       Comedy,Crime,Thriller
# tt6878306               News of the World      Action,Adventure,Drama
# tt7510346                     The Turning        Drama,Horror,Mystery
# tt7435316                     The Glorias     Biography,Drama,History
# tt2420124                           Wendy               Drama,Fantasy
# tt10243992                 I'm Your Woman                 Crime,Drama
# tt12888358  John Williams: Live in Vienna                       Music
# tt5198068                     Wolfwalkers  Adventure,Animation,Family
# tt6723592                           Tenet      Action,Sci-Fi,Thriller
# tt10649016                         Safety       Biography,Drama,Sport
# tt2850386           The Croods: A New Age  Adventure,Animation,Comedy
# tt11327514                    Uncle Frank                Comedy,Drama
# tt6199572                          Capone       Biography,Crime,Drama
# tt0805647                     The Witches     Adventure,Comedy,Family
#
#             runtimeMinutes                                            summary  \
# tconst
# tt1070874            129.0  The story of 7 people on trial stemming from v...
# tt9893250            118.0  A crooked legal guardian who drains the saving...
# tt6878306            118.0  A Civil War veteran agrees to deliver a girl, ...
# tt7510346             94.0  A young governess is hired to look after an or...
# tt7435316            139.0  The story of feminist icon Gloria Steinem's it...
# tt2420124            111.0  Lost on a mysterious island where aging and ti...
# tt10243992           120.0  In this 1970s set crime drama, a woman is forc...
# tt12888358           128.0  Explore the live recordings of the Hollywood l...
# tt5198068            103.0  A young apprentice hunter and her father journ...
# tt6723592            150.0  Armed with only one word, Tenet, and fighting ...
# tt10649016           122.0  The story of Ray-Ray McElrathbey, a freshman f...
# tt2850386             95.0  The prehistoric family the Croods are challeng...
# tt11327514            95.0  In 1973, when Frank Bledsoe and his 18-year-ol...
# tt6199572            103.0  The 47-year old Al Capone, after 10 years in p...
# tt0805647            106.0  A young boy and his grandmother have a run-in ...
#
#                                                   produced_by  \
# tconst
# tt1070874    Dreamworks Pictures, Amblin Partners, Apertur...
# tt9893250                  Black Bear Pictures, Crimple Beck
# tt6878306    Perfect World Pictures, Playtone, Pretty Pict...
# tt7510346    Dreamworks Pictures, Reliance Entertainment, ...
# tt7435316    Artemis Rising Foundation, Page Fifty-Four Pi...
# tt2420124    Fox Searchlight Pictures, TSG Entertainment, ...
# tt10243992   Big Indie Pictures, Original Headquarters, Sc...
# tt12888358   Bernhard Fleischer Moving Images, ServusTV, D...
# tt5198068    Apple Original Films, Cartoon Saloon, Mélusin...
# tt6723592                              Warner Bros., Syncopy
# tt10649016   Select Films, The Walt Disney Company, Walt D...
# tt2850386                               DreamWorks Animation
# tt11327514   Amazon Studios, Miramax Films, Your Face Goes...
# tt6199572     BRON Studios, A Band Apart, Addictive Pictures
# tt0805647    Warner Bros., ImageMovers, Canadian Film or V...
#
#                       rel_date   budget_USD  usa_open_we  prev_Oscars  \
# tconst
# tt1070874      16 October 2020     242408.8          NaN         15.0
# tt9893250     19 February 2021     242408.8          NaN          8.0
# tt6878306     25 December 2020     242408.8    2250430.0         32.0
# tt7510346      24 January 2020   14000000.0    6950045.0          2.0
# tt7435316    30 September 2020     242408.8          NaN         21.0
# tt2420124        17 April 2020    6000000.0      26214.0          2.0
# tt10243992    11 December 2020     242408.8          NaN          0.0
# tt12888358      2 October 2020     242408.8          NaN         21.0
# tt5198068     13 November 2020     242408.8          NaN          5.0
# tt6723592     3 September 2020  205000000.0   20200000.0         16.0
# tt10649016    11 December 2020     242408.8          NaN          3.0
# tt2850386     25 November 2020     242408.8    9724200.0         19.0
# tt11327514    25 November 2020     242408.8          NaN          9.0
# tt6199572          12 May 2020     242408.8          NaN         14.0
# tt0805647      22 October 2020     242408.8          NaN         35.0
#
#                              nominated_for
# tconst
# tt1070874                             None
# tt9893250    Nominated for 1 Golden Globe.
# tt6878306   Nominated for 2 Golden Globes.
# tt7510346                             None
# tt7435316                             None
# tt2420124                             None
# tt10243992                            None
# tt12888358                            None
# tt5198068    Nominated for 1 Golden Globe.
# tt6723592    Nominated for 1 Golden Globe.
# tt10649016                            None
# tt2850386    Nominated for 1 Golden Globe.
# tt11327514                            None
# tt6199572                             None
# tt0805647                             None

# %%
temp = movies_2020.loc[tto_bp_win_preds_top10_ind,['primaryTitle', 'genres', 'runtimeMinutes', 'summary', 'produced_by', 'rel_date', 'budget_USD', 'usa_open_we', 'prev_Oscars', 'nominated_for']]
temp.to_clipboard(excel = True)
